# %% [markdown]
# # Using Upstage Document Parse on SageMaker Jumpstart

# %% [markdown]
# Upstage Documnet Parse is a powerful API designed to automatically convert any document to HTML. It detects layout elements such as paragraphs, tables, images, and more to determine the structure of the document. The API then serializes the elements according to reading order, and finally converts the document into HTML.
#
# This sample notebook shows you how to deploy [Upstage Document Parse](https://aws.amazon.com/marketplace/pp/prodview-lv5bnpdco7xoq) using Amazon SageMaker.
#
# ## Pre-requisites:
#
# 1. **Note**: This notebook contains elements which render correctly in Jupyter interface. Open this notebook from an Amazon SageMaker Notebook Instance or Amazon SageMaker Studio.
# 2. Ensure that IAM role used has **AmazonSageMakerFullAccess**
# 3. To deploy this ML model successfully, ensure that:
#    1. Either your IAM role has these three permissions and you have authority to make AWS Marketplace subscriptions in the AWS account used:
#       1. **aws-marketplace:ViewSubscriptions**
#       2. **aws-marketplace:Unsubscribe**
#       3. **aws-marketplace:Subscribe**
#
# ## Contents:
#
# 1. [Subscribe to the model package](#1.-Subscribe-to-the-model-package)
# 2. [Create an endpoint and perform real-time inference](#2.-Create-an-endpoint-and-perform-real-time-inference)
#    1. [Create an endpoint](#A.-Create-an-endpoint)
#    2. [Prepare input payload](#B.-Prepare-input-payload)
#    3. [Perform real-time inference](#C.-Perform-real-time-inference)
# 3. [Perform batch transform](#3.-Perform-batch-transform)
#    1. [Upload test files to S3](#A.-Upload-test-files-to-S3)
#    2. [Create a batch transform job](#B.-Create-a-batch-transform-job)
#    3. [Check results](#C.-Check-results)
# 4. [Clean-up](#4.-Clean-up)
#    1. [Delete the endpoint](#A.-Delete-the-endpoint)
#    2. [Delete the model](#B.-Delete-the-model)
#
# ## Usage instructions
#
# You can run this notebook one cell at a time (By using Shift+Enter for running a cell).

# %% [markdown]
# ## 1. Subscribe to the model package

# %% [markdown]
# To subscribe to the model package:
#
# 1. Open [Upstage Document Parse](https://aws.amazon.com/marketplace/pp/prodview-lv5bnpdco7xoq) model package listing page.
# 2. On the AWS Marketplace listing, click on the **Continue to subscribe** button.
# 3. On the **Subscribe to this software** page, review and click on **"Accept Offer"** if you and your organization agrees with EULA, pricing, and support terms.
# 4. Once you click on **Continue to configuration button** and then choose a **region**, you will see a **Product Arn** displayed. This is the model package ARN that you need to specify while creating a deployable model using Boto3. Copy the ARN corresponding to your region and specify the same in the following cell.

# %%
# %pip -q install sagemaker requests_toolbelt boto3

# %%
import os
import boto3
import sagemaker
from sagemaker import ModelPackage

# %%
boto_session = boto3.Session()
sm_session = sagemaker.Session(boto_session=boto_session)

try:
    role = sagemaker.get_execution_role()
except ValueError:
    iam = boto_session.client("iam")
    role = [r for r in iam.list_roles()["Roles"] if r["RoleName"].startswith("AmazonSageMaker-ExecutionRole")][0]["Arn"]

# %%
# Select the appropriate model package name based on the instance type
# 260128.1 version
model_package_name = "document-parse-260128-1-cu118-97d08e83914a3a718ed1cbe6dbe6e889"

# Mapping for Model Packages
model_package_map = {
    "us-east-1": f"arn:aws:sagemaker:us-east-1:865070037744:model-package/{model_package_name}",
    "us-east-2": f"arn:aws:sagemaker:us-east-2:057799348421:model-package/{model_package_name}",
    "us-west-1": f"arn:aws:sagemaker:us-west-1:382657785993:model-package/{model_package_name}",
    "us-west-2": f"arn:aws:sagemaker:us-west-2:594846645681:model-package/{model_package_name}",
    "ca-central-1": f"arn:aws:sagemaker:ca-central-1:470592106596:model-package/{model_package_name}",
    "eu-central-1": f"arn:aws:sagemaker:eu-central-1:446921602837:model-package/{model_package_name}",
    "eu-west-1": f"arn:aws:sagemaker:eu-west-1:985815980388:model-package/{model_package_name}",
    "eu-west-2": f"arn:aws:sagemaker:eu-west-2:856760150666:model-package/{model_package_name}",
    "eu-west-3": f"arn:aws:sagemaker:eu-west-3:843114510376:model-package/{model_package_name}",
    "eu-north-1": f"arn:aws:sagemaker:eu-north-1:136758871317:model-package/{model_package_name}",
    "ap-southeast-1": f"arn:aws:sagemaker:ap-southeast-1:192199979996:model-package/{model_package_name}",
    "ap-southeast-2": f"arn:aws:sagemaker:ap-southeast-2:666831318237:model-package/{model_package_name}",
    "ap-northeast-2": f"arn:aws:sagemaker:ap-northeast-2:745090734665:model-package/{model_package_name}",
    "ap-northeast-1": f"arn:aws:sagemaker:ap-northeast-1:977537786026:model-package/{model_package_name}",
    "ap-south-1": f"arn:aws:sagemaker:ap-south-1:077584701553:model-package/{model_package_name}",
    "sa-east-1": f"arn:aws:sagemaker:sa-east-1:270155090741:model-package/{model_package_name}",
}

region = sm_session.boto_region_name
if region not in model_package_map.keys():
    raise Exception(f"Current boto3 session region {region} is not supported.")

model_package_arn = model_package_map[region]

print(f"Model Package: '{model_package_arn}'")

# %% [markdown]
# ## 2. Create an endpoint and perform real-time inference

# %% [markdown]
# If you want to understand how real-time inference with Amazon SageMaker works, see [Documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/how-it-works-hosting.html).

# %%
model_name = "Upstage-Document-Parse"

real_time_inference_instance_type = (
    "ml.g6.2xlarge"
)

# %% [markdown]
# ### A. Create an endpoint

# %%
# create a deployable model from the model package.
model = ModelPackage(
    role=role, model_package_arn=model_package_arn, sagemaker_session=sm_session
)

endpoint_name = sagemaker.utils.name_from_base(model_name)
print(f"endpoint name: '{endpoint_name}'")

# %%
# Deploy the model
model.deploy(1, real_time_inference_instance_type, endpoint_name=endpoint_name)

# %% [markdown]
# Once endpoint has been created, you would be able to perform real-time inference.

# %% [markdown]
# ### B. Prepare input payload

# %% [markdown]
# We support JPEG, PNG, BMP, PDF, TIFF, HEIC, DOCX, PPTX, XLSX formats.

# %% [markdown]
# ### C. Perform real-time inference

# %%
import boto3
import json
from requests_toolbelt import MultipartEncoder

runtime_sm_client = boto3.client("runtime.sagemaker")

# Prepare multipart form data
m = MultipartEncoder(
    fields={
        "document": ("sample_1.png", open("sample_1.png", "rb"), "image/png"),
        # 'document': ('solar.pdf', open('solar.pdf', 'rb'), 'application/pdf'), # for PDF files
        "model": "document-parse",
        "ocr": "force",
        "coordinates": "true",
        "output_formats": '["text", "html", "markdown"]',
        "base64_encoding": '["table"]',
        "chart_recognition": "true",
    }
)

# Get the raw bytes of the multipart form data
body = m.to_string()

response = runtime_sm_client.invoke_endpoint(
    EndpointName=endpoint_name,
    ContentType=m.content_type,  # This will be 'multipart/form-data; boundary=...'
    Body=body,
)

result = response["Body"].read()

# Print the result
print("output:", json.loads(result))

# %% [markdown]
# ## 3. Perform batch transform
#
# Batch Transform allows you to process large datasets stored in S3 without deploying a persistent endpoint. This is useful when you have many documents to process at once.
#
# Document Parse supports `application/octet-stream` as the content type for batch transform, which automatically detects file types (PDF, JPEG, PNG, DOCX, PPTX, HWP, etc.) from binary content. This means you can mix different file formats in a single batch transform job.

# %% [markdown]
# ### A. Upload test files to S3
#
# Upload your documents to an S3 bucket. You can mix different file formats (PDF, JPEG, DOCX, PPTX, etc.) in the same input directory.

# %%
import os

# S3 bucket and prefix for batch transform
default_bucket = sm_session.default_bucket()
default_bucket = "upstage-marketplace-test-assets" # Replace with your bucket name if not using the default
batch_input_prefix = "document-parse/input"
batch_output_prefix = "document-parse/output"

# Upload local files to S3
# Replace these with your own document files
sample_files = ["sample_1.png"]  # Add more files: "report.pdf", "slides.pptx", etc.

for f in sample_files:
    if os.path.exists(f):
        s3_key = f"{batch_input_prefix}/{f}"
        boto3.client("s3").upload_file(f, default_bucket, s3_key)
        print(f"Uploaded: s3://{default_bucket}/{s3_key}")

print(f"\nInput path: s3://{default_bucket}/{batch_input_prefix}/")

# %% [markdown]
# ### B. Create a batch transform job
#
# Create a batch transform job using the same model package. We use `application/octet-stream` as the content type so the container automatically detects file types from binary content. This allows mixing different file formats (PDF, JPEG, DOCX, PPTX, etc.) in a single job.

# %%
batch_transform_instance_type = (
    "ml.g5.2xlarge"
)

# Create a batch transform job
batch_model = ModelPackage(
    role=role, model_package_arn=model_package_arn, sagemaker_session=sm_session
)

transformer = batch_model.transformer(
    instance_count=1,
    instance_type=batch_transform_instance_type,
    output_path=f"s3://{default_bucket}/{batch_output_prefix}/",
    max_payload=50,  # Maximum payload size in MB
)

transformer.transform(
    data=f"s3://{default_bucket}/{batch_input_prefix}/",
    content_type="application/octet-stream",  # Auto-detect file type from binary content
    split_type="None",  # Each file is sent as a single request
    model_client_config={
        "InvocationsTimeoutInSeconds": 300,  # 5 minutes per document
    },
    wait=True,
)

print(f"\nBatch transform completed!")
print(f"Output: s3://{default_bucket}/{batch_output_prefix}/")

# %% [markdown]
# ### C. Check results
#
# Each input file produces a corresponding `.out` file in the output S3 path containing the JSON result.

# %%
import json

s3_client = boto3.client("s3")

# List output files
response = s3_client.list_objects_v2(Bucket=default_bucket, Prefix=batch_output_prefix)

for obj in response.get("Contents", []):
    key = obj["Key"]
    filename = key.split("/")[-1]
    if not filename.endswith(".out"):
        continue

    # Download and parse the result
    result = s3_client.get_object(Bucket=default_bucket, Key=key)
    body = result["Body"].read().decode("utf-8")
    data = json.loads(body)

    # Print summary
    elements = data.get("elements", [])
    print(f"{filename}: {len(elements)} elements detected")
    for elem in elements[:3]:  # Show first 3 elements
        print(f"  - [{elem['category']}] {elem.get('content', {}).get('text', '')[:80]}")
    if len(elements) > 3:
        print(f"  ... and {len(elements) - 3} more elements")

# %% [markdown]
# ## 4. Clean-up

# %% [markdown]
# ### A. Delete the endpoint

# %% [markdown]
# Now that you have successfully performed a real-time inference, you can delete the endpoint and avoid being charged.

# %%
model.sagemaker_session.delete_endpoint(endpoint_name)
model.sagemaker_session.delete_endpoint_config(endpoint_name)

# %% [markdown]
# ### B. Delete the model

# %%
model.delete_model()
